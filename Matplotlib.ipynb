# %% [markdown]
# <a href="https://colab.research.google.com/github/hussain2505/ML_LAB_2026-27/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Simple Line Plot

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 30, 25]

plt.plot(x, y)

plt.show()

# %% [markdown]
# Add Title and Labels

# %%
plt.plot(x, y)

plt.title("My First Graph")
plt.xlabel("X Values")
plt.ylabel("Y Values")

plt.show()

# %% [markdown]
# Line Plot

# %%
import pandas as pd
data = {
    "Name": ["Ali", "Rahul", "John", "Ravi", "Sai", "Jack"],
    "Age": [20, 21, 22, 23, 20, 21],
    "Marks": [85, 90, 78, 92, 89, 65]
}
df = pd.DataFrame(data)
plt.plot(df["Name"], df["Marks"])
plt.title("Student Marks")
plt.xlabel("Student")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# Change Line Style

# %%
plt.plot(df["Name"], df["Marks"], linestyle="--")

plt.show()

# %% [markdown]
# Dotted line

# %%
plt.plot(df["Name"], df["Marks"], linestyle=":")

plt.show()

# %% [markdown]
# Different markers

# %%
plt.plot(df["Name"], df["Marks"], marker="o")

plt.show()

# %% [markdown]
# Line Width

# %%
plt.plot(df["Name"], df["Marks"], linewidth=3)

plt.show()

# %% [markdown]
# Figure Size

# %%
plt.figure(figsize=(10, 5))

plt.plot(df["Name"], df["Marks"])

plt.title("Student Marks")

plt.show()

# %% [markdown]
# X-axis and Y-axis Limits

# %%
plt.plot(df["Age"], df["Marks"])

plt.xlim(19, 24)
plt.ylim(50, 100)

plt.show()

# %% [markdown]
# Add Text to Graph

# %%
plt.plot(df["Name"], df["Marks"])

plt.text(0, 85, "85")

plt.show()

# %% [markdown]
# Save Your Graph

# %%
plt.plot(df["Name"], df["Marks"])

plt.savefig("student_marks.png")

plt.show()

# %% [markdown]
# Bar Chart

# %%
plt.bar(df["Name"], df["Marks"])

plt.title("Student Marks")
plt.xlabel("Name")
plt.ylabel("Marks")

plt.show()

# %% [markdown]
# Scatter Plot

# %%
plt.scatter(df["Age"], df["Marks"])

plt.title("Age vs Marks")
plt.xlabel("Age")
plt.ylabel("Marks")

plt.show()

# %% [markdown]
# Histogram

# %%
plt.hist(df["Marks"])

plt.title("Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Number of Students")

plt.show()

# %% [markdown]
# Pie Chart

# %%
cities = ["Hyderabad", "Delhi", "Mumbai"]
students = [40, 30, 30]

plt.pie(students, labels=cities)

plt.title("Students by City")

plt.show()

# %% [markdown]
# Grid

# %%
plt.plot(df["Name"], df["Marks"])

plt.grid()

plt.show()

# %% [markdown]
# Subplots

# %%
plt.subplot(2, 2, 1)

plt.plot(df["Name"], df["Marks"])
plt.title("Line")

plt.subplot(2, 2, 2)

plt.bar(df["Name"], df["Marks"])
plt.title("Bar")

plt.subplot(2, 2, 3)

plt.scatter(df["Age"], df["Marks"])
plt.title("Scatter")

plt.subplot(2, 2, 4)

plt.hist(df["Marks"])
plt.title("Histogram")

plt.tight_layout()

plt.show()

# %% [markdown]
# Read CSV and Visualize

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("sampledata.csv")

plt.bar(df["Name"], df["Marks"])
plt.title("Student Marks")
plt.xlabel("Name")
plt.ylabel("Marks")

plt.show()

# %% [markdown]
# Graphs

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read CSV file
df = pd.read_csv("sampledata.csv")

# Create 2 rows × 3 columns
plt.figure(figsize=(15, 8))

# 1. Bar Chart
plt.subplot(2, 3, 1)
plt.bar(df["Name"], df["Marks"])
plt.title("Bar Chart")
plt.xlabel("Name")
plt.ylabel("Marks")

# 2. Line Chart
plt.subplot(2, 3, 2)
plt.plot(df["Name"], df["Marks"], marker="o")
plt.title("Line Chart")
plt.xlabel("Name")
plt.ylabel("Marks")

# 3. Scatter Plot
plt.subplot(2, 3, 3)
plt.scatter(df["Age"], df["Marks"])
plt.title("Scatter Plot")
plt.xlabel("Age")
plt.ylabel("Marks")

# 4. Histogram
plt.subplot(2, 3, 4)
plt.hist(df["Marks"], bins=5)
plt.title("Histogram")
plt.xlabel("Marks")
plt.ylabel("Frequency")

# 5. Pie Chart
plt.subplot(2, 3, 5)
plt.pie(df["Marks"], labels=df["Name"], autopct="%1.1f%%")
plt.title("Pie Chart")

# Automatically adjust spacing
plt.tight_layout()

# Display all graphs
plt.show()
