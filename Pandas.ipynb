# %% [markdown]
# <a href="https://colab.research.google.com/github/hussain2505/ML_LAB_2026-27/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# pandas

# %%
import pandas as pd

# %% [markdown]
# Dataframe

# %%
data = {
    "Name": ["Ali", "Rahul", "John","Ravi","Sai","Jack"],
    "Age": [20, 21, 22,23,20,21],
    "Marks": [85, 90, 78,92,89,65]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age  Marks
# 0    Ali   20     85
# 1  Rahul   21     90
# 2   John   22     78
# 3   Ravi   23     92
# 4    Sai   20     89
# 5   Jack   21     65

# %% [markdown]
# Display data

# %%
df.head()#first five rows
# Out:
#     Name  Age  Marks
# 0    Ali   20     85
# 1  Rahul   21     90
# 2   John   22     78
# 3   Ravi   23     92
# 4    Sai   20     89

# %%
df.head(3)#given rows of index
# Out:
#     Name  Age  Marks
# 0    Ali   20     85
# 1  Rahul   21     90
# 2   John   22     78

# %%
df.tail()#last five rows
# Out:
#     Name  Age  Marks
# 1  Rahul   21     90
# 2   John   22     78
# 3   Ravi   23     92
# 4    Sai   20     89
# 5   Jack   21     65

# %%
df.tail(2)#given rows of index
# Out:
#    Name  Age  Marks
# 4   Sai   20     89
# 5  Jack   21     65

# %% [markdown]
# Check dataset information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     6 non-null      int64
#  2   Marks   6 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 276.0+ bytes

# %% [markdown]
# Check rows and columns

# %%
df.shape
# Out:
# (6, 3)

# %%
df.columns   #give the columns
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='object')

# %% [markdown]
# Select a column

# %%
df["Age"]
# Out:
# 0    20
# 1    21
# 2    22
# 3    23
# 4    20
# 5    21
# Name: Age, dtype: int64

# %%
df[["Name", "Age"]]
# Out:
#     Name  Age
# 0    Ali   20
# 1  Rahul   21
# 2   John   22
# 3   Ravi   23
# 4    Sai   20
# 5   Jack   21

# %% [markdown]
# Select rows

# %%
df.iloc[0]
# Out:
# Name     Ali
# Age       20
# Marks     85
# Name: 0, dtype: object

# %%
df.iloc[0:3]   #continues give the rows
# Out:
#     Name  Age  Marks
# 0    Ali   20     85
# 1  Rahul   21     90
# 2   John   22     78

# %% [markdown]
# Filter data

# %%
df[df["Marks"] > 80]
# Out:
#     Name  Age  Marks
# 0    Ali   20     85
# 1  Rahul   21     90
# 3   Ravi   23     92
# 4    Sai   20     89

# %%
df[df["Marks"] < 80]
# Out:
#    Name  Age  Marks
# 2  John   22     78
# 5  Jack   21     65

# %% [markdown]
# Basic statistics

# %%
df["Marks"].mean()
# Out:
# np.float64(83.16666666666667)

# %%
df["Marks"].max()
# Out:
# 92

# %%
df["Marks"].min()
# Out:
# 65

# %%
df["Marks"].sum()
# Out:
# np.int64(499)

# %% [markdown]
# Missing values

# %%
import pandas as pd


data = {
    "Name": ["Ali", "Rahul", "John", "Sara", "David"],
    "Age": [20, np.nan, 22, 21, np.nan],
    "Marks": [85, 90, np.nan, 78, 88]
}

df = pd.DataFrame(data)

print(df)
print(df.isnull())
# Out:
#     Name   Age  Marks
# 0    Ali  20.0   85.0
# 1  Rahul   NaN   90.0
# 2   John  22.0    NaN
# 3   Sara  21.0   78.0
# 4  David   NaN   88.0
#     Name    Age  Marks
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3  False  False  False
# 4  False   True  False

# %% [markdown]
# Fill missing values

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())

print(df)
# Out:
#     Name   Age  Marks
# 0    Ali  20.0  85.00
# 1  Rahul  21.0  90.00
# 2   John  22.0  85.25
# 3   Sara  21.0  78.00
# 4  David  21.0  88.00

# %% [markdown]
# Remove missing values

# %%
import pandas as pd


data = {
    "Name": ["Ali", "Rahul", "John", "Sara", "David"],
    "Age": [20, np.nan, 22, 21, np.nan],
    "Marks": [85, 90, np.nan, 78, 88]
}

df = pd.DataFrame(data)
df = df.dropna()

print(df)
# Out:
#    Name   Age  Marks
# 0   Ali  20.0   85.0
# 3  Sara  21.0   78.0

# %% [markdown]
# Unique values

# %%
data = {
    "Name": ["Ali", "Rahul", "John","Ravi","Sai","Jack"],
    "Age": [20, 21, 22,23,20,21],
    "Marks": [85, 90, 78,92,89,65]
}

df = pd.DataFrame(data)
df["Name"].unique()
# Out:
# array(['Ali', 'Rahul', 'John', 'Ravi', 'Sai', 'Jack'], dtype=object)

# %%
df["Name"].nunique()#count the values
# Out:
# 6

# %% [markdown]
# Sort data

# %%
df.sort_values("Marks")
# Out:
#     Name  Age  Marks
# 5   Jack   21     65
# 2   John   22     78
# 0    Ali   20     85
# 4    Sai   20     89
# 1  Rahul   21     90
# 3   Ravi   23     92

# %%
df.sort_values("Marks", ascending=False) # higest marks
# Out:
#     Name  Age  Marks
# 3   Ravi   23     92
# 1  Rahul   21     90
# 4    Sai   20     89
# 0    Ali   20     85
# 2   John   22     78
# 5   Jack   21     65

# %% [markdown]
# Add a column

# %%
data = {
    "Name": ["Ali", "Rahul", "John","Ravi","Sai","Jack"],
    "Age": [20, 21, 22,23,20,21],
    "Marks": [85, 90, 78,92,89,65]
}

df["Pass"] = df["Marks"] >= 80
print(df)
# Out:
#     Name  Age  Marks   Pass
# 0    Ali   20     85   True
# 1  Rahul   21     90   True
# 2   John   22     78  False
# 3   Ravi   23     92   True
# 4    Sai   20     89   True
# 5   Jack   21     65  False

# %% [markdown]
# Delete a column

# %%
data = {
    "Name": ["Ali", "Rahul", "John"],
    "Marks": [85, 35, 70]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Marks
# 0    Ali     85
# 1  Rahul     35
# 2   John     70

# %% [markdown]
# Groupby

# %%
import pandas as pd

data = {
    "Name": ["Ali", "Rahul", "John", "Ravi", "Sai", "Jack"],
    "Age": [20, 21, 22, 23, 20, 21],
    "Marks": [85, 90, 78, 92, 89, 65]
}

df = pd.DataFrame(data)

result = df.groupby("Age")["Marks"].mean()

print(result)
# Out:
# Age
# 20    87.0
# 21    77.5
# 22    78.0
# 23    92.0
# Name: Marks, dtype: float64

# %% [markdown]
# Upload csv file

# %%
import pandas as pd

df = pd.read_csv("train.csv")

df.head()
# Out:
#    Student_ID    Name  Maths  Physics  Chemistry  English  Computer_Science  \
# 0           1   Aarav     85       78         82       88                91
# 1           2   Priya     92       89         91       94                96
# 2           3   Rahul     76       72         75       79                83
# 3           4  Ananya     88       91         86       90                94
# 4           5   Arjun     67       65         70       72                75
#
#    Total  Percentage Result
# 0    424        84.8   Pass
# 1    462        92.4   Pass
# 2    385        77.0   Pass
# 3    449        89.8   Pass
# 4    349        69.8   Pass
